# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
import pickle

with open('../data/batch_outcome.pkl', 'rb') as f:
    (w, b, log) = pickle.load(f)

# %%
x = np.array(range(1,len(log)+1))
training_loss = [e[0] for e in log]
norm_w = [e[1] for e in log]
norm_b = [e[2] for e in log]
# print (x)
# print (training_loss)
plt.figure()
plt.plot(x, training_loss, 'o')
plt.figure()
plt.plot(x, norm_w, '+')
